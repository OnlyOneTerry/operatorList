# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn;
from sklearn.linear_model import  LinearRegression
from scipy import  stats
import pylab as pl
seaborn.set()

# %%
from sklearn.datasets.samples_generator import make_blobs
X,y = make_blobs(n_samples= 50,centers = 2,
                random_state=0,cluster_std=0.60)

# %%
xfit = np.linspace(-1,3.5)#用于创建一个一维数组,并且是等差数列构成的一维数组
plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='spring')#绘制散点图
for m,b,d in [(1,0.65,0.33),(0.,1.6,0.55),(-0.2,2.9,0.2)]:
    yfit = m*xfit + b
    plt.plot(xfit,yfit,'-k')
    plt.fill_between(xfit,yfit-d,yfit+d,edgecolor='none',color='#AAAAAA',alpha=0.4)
plt.xlim(-1,3.5)
# Out:
# (-1, 3.5)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='linear')
clf.fit(X,y)

def plot_svc_decision_function(clf,ax=None):
    if ax is None:
        ax = plt.gca()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9df78d92de9b> in <module>()
#       1 from sklearn.svm import SVC
# ----> 2 clf = SVC(ker)
#
# NameError: name 'ker' is not defined
