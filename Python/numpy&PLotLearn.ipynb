# %%
import numpy as np

# %%
x  = np.arange(6)
print(x)
# Out:
# [0 1 2 3 4 5]

# %%
x = x.reshape((2,3))

# %%
x.shape
print(x.shape[0])
# Out:
# 2

# %%
np.zeros_like(x)
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]])

# %%
y = np.arange(3,dtype=np.float)
y
# Out:
# array([0., 1., 2.])

# %%
np.zeros_like(y)
# Out:
# array([0., 0., 0.])

# %%
y.shape
# Out:
# (3,)

# %%
def square(x):
    return x**2
list(map(square,[1,2,3,4,5]))
# Out:
# [1, 4, 9, 16, 25]

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)
print(type(ax1))
plt.show()
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
fig = plt.figure()
ax3 = fig.add_axes([0.1,0.1,0.8,0.8])
ax4 = fig.add_axes([0.72,0.72,0.16,0.16])
print(type(ax3))
plt.show()
# Out:
# <class 'matplotlib.axes._axes.Axes'>

# %%
x = np.arange(0,100)
plt.subplot(221)
plt.plot(x,x)
plt.subplot(222)
plt.plot(x,-x)
plt.subplot(223)
plt.plot(x,x**2)
plt.subplot(224)
plt.plot(x,np.log(x))
plt.show()
# Out:
# C:\Users\admin\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':
